# %% [markdown]
# ## Reading the Data

# %%
# import pandas library
import pandas as pd
import numpy as np

# %%
file_path = r"C:\Users\kmalangwasila\Desktop\Personal Documents\University of Bradford\SEMESTER 1 UNIVERSITY OF BRADFORD\Applied Machine Learning and Big Data Strategy\Lab3\countries of the world.csv"

# %%
df = pd.read_csv(file_path)

# %%
# Checking the top 5 rows using the dataframe.head() method
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df.tail()
# Out:
#              Country                               Region  Population  \
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 222            5860                       419.9                          0.00
# 223          266000                         1.0                          0.42
# 224          527970                        40.6                          0.36
# 225          752614                        15.3                          0.00
# 226          390580                        31.3                          0.00
#
# ...

# %% [markdown]
# we need to replace the "?" symbol with NaN so the dropna() can remove the missing values

# %%
df1=df.replace('?',np.NaN)

# %%
df=df1.dropna(subset=["GDP ($ per capita)"], axis=0)
df.head(10)
# Out:
#               Country                               Region  Population  \
# 0        Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1            Albania   EASTERN EUROPE                          3581655
# 2            Algeria   NORTHERN AFRICA                        32930091
# 3     American Samoa   OCEANIA                                   57794
# 4            Andorra   WESTERN EUROPE                            71201
# 5             Angola   SUB-SAHARAN AFRICA                     12127071
# 6           Anguilla               LATIN AMER. & CARIB           13477
# 7  Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8          Argentina               LATIN AMER. & CARIB        39921833
# 9            Armenia                  C.W. OF IND. STATES      2976372
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
df.to_csv("Countries_of_the _world data", index=False)

# %% [markdown]
# # Basic insights of data types

# %%
df.dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# Service                               float64
# dtype: object

# %% [markdown]
# # Getting a statistical summary of each column , for numeric typed (int, float)

# %%
df.describe()
# Out:
#          Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  2.260000e+02    2.260000e+02                  226.000000
# mean   2.886625e+07    5.996970e+05                  380.719912
# std    1.181377e+08    1.794119e+06                 1663.679301
# min    7.026000e+03    2.000000e+00                    0.000000
# 25%    4.425318e+05    4.407250e+03                   29.725000
# 50%    4.914957e+06    8.523500e+04                   79.150000
# 75%    1.757631e+07    4.441805e+05                  190.975000
# max    1.313974e+09    1.707520e+07                16271.500000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                    226.000000     224.000000
# mean                      21.257124       0.038125
# std                       72.434062       4.889269
# min                        0.000000     -20.990000
# 25%                        0.100000      -0.927500
# 50%                        0.760000       0.000000
# ...

# %% [markdown]
# # Statistical summary for all columns

# %%
df.describe(include = "all")
# Out:
#                 Country                               Region    Population  \
# count               226                                  226  2.260000e+02
# unique              226                                   11           NaN
# top     Czech Republic   SUB-SAHARAN AFRICA                            NaN
# freq                  1                                   51           NaN
# mean                NaN                                  NaN  2.886625e+07
# std                 NaN                                  NaN  1.181377e+08
# min                 NaN                                  NaN  7.026000e+03
# 25%                 NaN                                  NaN  4.425318e+05
# 50%                 NaN                                  NaN  4.914957e+06
# 75%                 NaN                                  NaN  1.757631e+07
# max                 NaN                                  NaN  1.313974e+09
#
#         Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# ...

# %% [markdown]
# further Information about the dataframe.
# It provide a concise summary of your DataFrame.
#
# This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 226 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             226 non-null    object
#  1   Region                              226 non-null    object
#  2   Population                          226 non-null    int64
#  3   Area (sq. mi.)                      226 non-null    int64
#  4   Pop. Density (per sq. mi.)          226 non-null    float64
#  5   Coastline (coast/area ratio)        226 non-null    float64
#  6   Net migration                       224 non-null    float64
#  7   Infant mortality (per 1000 births)  224 non-null    float64
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    float64
#  10  Phones (per 1000)                   223 non-null    float64
# ...

# %% [markdown]
# # Data Wrangling, to achieve better analysis

# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %% [markdown]
# # Identifying and handling missing values

# %%
import numpy as np
# replace "?" to NaN
df.replace("?", np.nan, inplace = True)
df.head()
# Out:
# C:\Users\kmalangwasila\Anaconda3\lib\site-packages\pandas\core\frame.py:4379: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# ...

# %% [markdown]
# # Identifying missing values using isnull method

# %% [markdown]
# the output is a boolean value

# %%
missing_data = df.isnull()
missing_data.head()
# Out:
#    Country  Region  Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0    False   False       False           False                       False
# 1    False   False       False           False                       False
# 2    False   False       False           False                       False
# 3    False   False       False           False                       False
# 4    False   False       False           False                       False
#
#    Coastline (coast/area ratio)  Net migration  \
# 0                         False          False
# 1                         False          False
# 2                         False          False
# 3                         False          False
# 4                         False          False
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 0                               False               False         False
# 1                               False               False         False
# ...

# %% [markdown]
# # Counting missing values in each column

# %% [markdown]
# we use a for loop in python

# %%
for column in missing_data.columns.values.tolist():
    print (column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Country
# False    226
# Name: Country, dtype: int64
#
# Region
# False    226
# Name: Region, dtype: int64
#
# Population
# False    226
# Name: Population, dtype: int64
#
# Area (sq. mi.)
# False    226
# Name: Area (sq. mi.), dtype: int64
#
# Pop. Density (per sq. mi.)
# False    226
# Name: Pop. Density (per sq. mi.), dtype: int64
#
# Coastline (coast/area ratio)
# False    226
# Name: Coastline (coast/area ratio), dtype: int64
#
# Net migration
# False    224
# True       2
# Name: Net migration, dtype: int64
#
# Infant mortality (per 1000 births)
# False    224
# True       2
# Name: Infant mortality (per 1000 births), dtype: int64
#
# GDP ($ per capita)
# False    226
# Name: GDP ($ per capita), dtype: int64
#
# Literacy (%)
# False    209
# True      17
# Name: Literacy (%), dtype: int64
#
# Phones (per 1000)
# False    223
# True       3
# Name: Phones (per 1000), dtype: int64
#
# Arable (%)
# False    224
# True       2
# Name: Arable (%), dtype: int64
#
# Crops (%)
# ...

# %% [markdown]
# Missing data columns summary:
# Each column has 226 rows and the following columns contain missing data

# %% [markdown]
# 1."Net migration": 2 missing data\
# 2."Infant mortality (per 1000 births)": 2 missing data\
# 3."Literacy (%)": 17 missing data\
# 4."Phones(per 1000)": 3 missing data\
# 5."Arable (%)": 2 missing data\
# 6."Crops (%)": 2 missing data\
# 7."Other"(%): 2 missing data\
# 8."Climate": 22 missing data\
# 9."Birthrate": 2 missing data\
# 10."Deathrate": 3 missing data\
# 11."Agrictulture": 14 missing data\
# 12."Industry": 15 missing data\
# 13."Service": 15 missing data

# %% [markdown]
# # Handling the missing data

# %% [markdown]
# Replacing by mean except for climate which will be replaced by mode

# %% [markdown]
# # Calculating the mean value of Net migration column

# %%
avg_Net_migration = df["Net migration"].astype("float").mean(axis=0)
print("Average of Net migration:", avg_Net_migration)
# Out:
# Average of Net migration: 0.038125

# %% [markdown]
# Replace "NaN" by mean value in "Net migration" column

# %%
df["Net migration"].replace(np.nan, avg_Net_migration, inplace=True)
# Out:
# C:\Users\kmalangwasila\Anaconda3\lib\site-packages\pandas\core\series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %% [markdown]
# # Mean value of Infant mortality (per 1000 births)

# %%
avg_inf_mort= df["Infant mortality (per 1000 births)"].astype("float").mean(axis=0)
print("Average of Infant mortality(per 1000 births):", avg_inf_mort)
# Out:
# Average of Infant mortality(per 1000 births): 35.50696428571427

# %% [markdown]
# Replace "NaN" by mean value "in Infant mortality (per 1000 births)" column

# %%
df["Infant mortality (per 1000 births)"].replace(np.nan, avg_inf_mort, inplace=True)

# %% [markdown]
# # Mean value of Literacy (%)

# %%
avg_Literacy= df["Literacy (%)"].astype("float").mean(axis=0)
print("Average of Literacy (%):", avg_Literacy)
# Out:
# Average of Literacy (%): 82.83827751196172

# %% [markdown]
# Replacing "NaN" by mean value in "Literacy (%)" column

# %%
df["Literacy (%)"].replace(np.nan, avg_Literacy, inplace=True)

# %% [markdown]
# # Mean value of phones(per 1000)

# %%
avg_Phones= df["Phones (per 1000)"].astype("float").mean(axis=0)
print("Phone (per 1000):", avg_Phones)
# Out:
# Phone (per 1000): 236.06143497757856

# %% [markdown]
# Replacing "NaN" by mean value in "Phones (per 1000)" column

# %%
df["Phones (per 1000)"].replace(np.nan, avg_Phones, inplace=True)

# %% [markdown]
# # Mean value of Arable (%)

# %%
avg_Arable= df["Arable (%)"].astype("float").mean(axis=0)
print("Arable (%):", avg_Arable)
# Out:
# Arable (%): 13.858616071428562

# %% [markdown]
# Replacing "NaN" by mean value in "Arable (%)" column

# %%
df["Arable (%)"].replace(np.nan, avg_Arable, inplace=True)

# %% [markdown]
# # Mean value of crops(%)

# %%
avg_Crop= df["Crops (%)"].astype("float").mean(axis=0)
print("Crops (%):", avg_Crop)
# Out:
# Crops (%): 4.584598214285714

# %% [markdown]
# Replace "NaN" by mean value in "Crops (%)" column

# %%
df["Crops (%)"].replace(np.nan, avg_Crop, inplace=True)

# %% [markdown]
# # Mean Value of Other (%)

# %%
avg_Other = df["Other (%)"].astype("float").mean(axis=0)
print(" Other (%):", avg_Other)
# Out:
#  Other (%): 81.55642857142867

# %% [markdown]
# Replace "NaN" by mean value in "Other (%)" column

# %%
df["Other (%)"].replace(np.nan, avg_Other, inplace=True)

# %% [markdown]
# # To check which values are present in a particular column: To identify the frequent Climate value

# %%
df["Climate"].value_counts()
# Out:
# 2.0    111
# 3.0     48
# 1.0     28
# 1.5      8
# 4.0      6
# 2.5      3
# Name: Climate, dtype: int64

# %% [markdown]
# 2.0 is the most common type. use the ".idxmax()" method to calculate for us the most common type automatically:

# %%
df['Climate'].value_counts().idxmax()
# Out:
# 2.0

# %% [markdown]
# Replacing "NaN" with the most frequent climate value in the "Climate" column

# %%
df["Climate"].replace(np.nan, "2.0", inplace=True)

# %% [markdown]
# # Mean Value of Birthrate

# %%
avg_Birthrate = df["Birthrate"].astype("float").mean(axis=0)
print("Birthrate:", avg_Birthrate)
# Out:
# Birthrate: 22.114732142857147

# %% [markdown]
# Replacing "NaN" by mean value in "Bithrate" column

# %%
df["Birthrate"].replace(np.nan, avg_Birthrate, inplace=True)

# %% [markdown]
# # Mean Value of Deathrate

# %%
avg_Deathrate = df["Deathrate"].astype("float").mean(axis=0)
print("Deathrate:", avg_Deathrate)
# Out:
# Deathrate: 9.241345291479824

# %% [markdown]
# Replacing "NaN" by mean value in "Deathrate" column

# %%
df["Deathrate"].replace(np.nan, avg_Deathrate, inplace=True)

# %% [markdown]
# # Mean Value of Agriculture

# %%
avg_Agri = df["Agriculture"].astype("float").mean(axis=0)
print("Agriculture:", avg_Agri)
# Out:
# Agriculture: 0.15084433962264152

# %% [markdown]
# Replace "NaN" by mean value in "Agriculture" column

# %%
df["Agriculture"].replace(np.nan, avg_Agri, inplace=True)

# %% [markdown]
# # Mean Value of Industry

# %%
avg_Indu = df["Industry"].astype("float").mean(axis=0)
print("Industry:", avg_Indu)
# Out:
# Industry: 0.2827109004739337

# %% [markdown]
# Replace "NaN" by mean value in "Industry" column

# %%
df["Industry"].replace(np.nan, avg_Indu, inplace=True)

# %% [markdown]
# # Mean Value of Service

# %%
avg_Serv= df["Service"].astype("float").mean(axis=0)
print("Service:", avg_Serv)
# Out:
# Service: 0.5660663507109006

# %% [markdown]
# Replace "NaN" by mean value in "Service" column

# %%
df["Service"].replace(np.nan, avg_Serv, inplace=True)

# %% [markdown]
# # Checking our Dataframe with no missing values now!

# %%
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
missing_data = df.isnull()
missing_data.head()
# Out:
#    Country  Region  Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0    False   False       False           False                       False
# 1    False   False       False           False                       False
# 2    False   False       False           False                       False
# 3    False   False       False           False                       False
# 4    False   False       False           False                       False
#
#    Coastline (coast/area ratio)  Net migration  \
# 0                         False          False
# 1                         False          False
# 2                         False          False
# 3                         False          False
# 4                         False          False
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 0                               False               False         False
# 1                               False               False         False
# ...

# %% [markdown]
# # Making sure that we have correct data format

# %%
df.dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                                object
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# Service                               float64
# dtype: object

# %% [markdown]
# # Converting data type to a proper format

# %%
df[["Climate"]] = df[["Climate"]].astype("float")

# %%
df.dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# Service                               float64
# dtype: object

# %%
df["Region"].value_counts()
# Out:
# SUB-SAHARAN AFRICA                     51
# LATIN AMER. & CARIB                    45
# ASIA (EX. NEAR EAST)                   28
# WESTERN EUROPE                         28
# OCEANIA                                21
# NEAR EAST                              16
# C.W. OF IND. STATES                    12
# EASTERN EUROPE                         12
# NORTHERN AMERICA                        5
# NORTHERN AFRICA                         5
# BALTICS                                 3
# Name: Region, dtype: int64

# %% [markdown]
# # Binning to help with group analysis by placing the variables in bins

# %% [markdown]
# Visualizing the histogram of Literacy levels to appreciate how the distribution looks like

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["Literacy (%)"])

# set x/y labels and plot title
plt.pyplot.xlabel("Literacy (%)")
plt.pyplot.ylabel("count")
plt.pyplot.title("Literacy (%) bins")
# Out:
# Text(0.5, 1.0, 'Literacy (%) bins')

# %% [markdown]
# Building 3 bins hence calling for 4 dividers

# %%
bins = np.linspace(min(df["Literacy (%)"]), max(df["Literacy (%)"]), 4)
bins
# Out:
# array([ 17.6       ,  45.06666667,  72.53333333, 100.        ])

# %% [markdown]
# Setting up group names for the bins

# %%
group_names =["High", "Medium", "Low"]

# %%
df["Literacy (%) -binned"] = pd.cut(df["Literacy (%)"], bins, labels=group_names, include_lowest=True )
df[["Literacy (%)","Literacy (%) -binned"]].head(20)
# Out:
# <ipython-input-533-59ccccd7e45c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Literacy (%) -binned"] = pd.cut(df["Literacy (%)"], bins, labels=group_names, include_lowest=True )
#     Literacy (%) Literacy (%) -binned
# 0           36.0                 High
# 1           86.5                  Low
# 2           70.0               Medium
# 3           97.0                  Low
# 4          100.0                  Low
# 5           42.0                 High
# 6           95.0                  Low
# 7           89.0                  Low
# 8           97.1                  Low
# 9           98.6                  Low
# 10          97.0                  Low
# 11         100.0                  Low
# 12          98.0                  Low
# ...

# %% [markdown]
# Checking the Literacy levels in each bin

# %%
df["Literacy (%) -binned"].value_counts()
# Out:
# Low       173
# Medium     37
# High       16
# Name: Literacy (%) -binned, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, df["Literacy (%) -binned"].value_counts())

# set x/y labels and plot title
plt.pyplot.xlabel("Literacy (%) -binned")
plt.pyplot.ylabel("count")
plt.pyplot.title("Literacy (%) bins")
# Out:
# Text(0.5, 1.0, 'Literacy (%) bins')

# %% [markdown]
# Transforming the Literacy (%) binned to dummy variables

# %%
dummy_variable_1 = pd.get_dummies(df["Literacy (%) -binned"])
dummy_variable_1.head(10)
# Out:
#    High  Medium  Low
# 0     1       0    0
# 1     0       0    1
# 2     0       1    0
# 3     0       0    1
# 4     0       0    1
# 5     1       0    0
# 6     0       0    1
# 7     0       0    1
# 8     0       0    1
# 9     0       0    1

# %%
dummy_variable_1.rename(columns={'High':'Literacy_level_High','Medium':'Literacy_level_Medium', 'Low':'Literacy_level_Low' }, inplace=True)
dummy_variable_1.head()
# Out:
#    Literacy_level_High  Literacy_level_Medium  Literacy_level_Low
# 0                    1                      0                   0
# 1                    0                      0                   1
# 2                    0                      1                   0
# 3                    0                      0                   1
# 4                    0                      0                   1

# %%
df = pd.concat([df, dummy_variable_1], axis=1)
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
# Saving the cleaned file
df.to_csv('Clean_Countries_df.csv')

# %% [markdown]
# # Exploratory: Establishing which variables have the most impact on the GDP ($per capita)

# %% [markdown]
# Target Variable: GDP ($ per capita)

# %% [markdown]
# # 1. Data Analysis in Python

# %%
import pandas as pd
import numpy as np

# %%
path = 'Clean_Countries_df.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0          Country                               Region  \
# 0           0     Afghanistan         ASIA (EX. NEAR EAST)
# 1           1         Albania   EASTERN EUROPE
# 2           2         Algeria   NORTHERN AFRICA
# 3           3  American Samoa   OCEANIA
# 4           4         Andorra   WESTERN EUROPE
#
#    Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0    31056997          647500                        48.0
# 1     3581655           28748                       124.6
# 2    32930091         2381740                        13.8
# 3       57794             199                       290.4
# 4       71201             468                       152.1
#
#    Coastline (coast/area ratio)  Net migration  \
# 0                          0.00          23.06
# 1                          1.26          -4.93
# 2                          0.04          -0.39
# 3                         58.29         -20.71
# 4                          0.00           6.60
#
# ...

# %% [markdown]
# # 2. Analyzing Individual Feature Patterns using Visualization

# %% [markdown]
# installing seaborn using the pip which is the python package manager.

# %%
# %%capture
! pip install seaborn

# %% [markdown]
# Importing visualisation packages

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Choosing visualization based on the type of the variable in question

# %%
print (df.dtypes)
# Out:
# Unnamed: 0                              int64
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# ...

# %% [markdown]
# Creating a Correlation Matrix between 'Int64' and 'float64' type of variables using "corr" method

# %%
df.corr()
# Out:
#                                     Unnamed: 0  Population  Area (sq. mi.)  \
# Unnamed: 0                            1.000000   -0.041546       -0.044319
# Population                           -0.041546    1.000000        0.469883
# Area (sq. mi.)                       -0.044319    0.469883        1.000000
# Pop. Density (per sq. mi.)            0.018191   -0.028442       -0.067118
# Coastline (coast/area ratio)          0.037794   -0.068528       -0.095889
# Net migration                        -0.017198    0.000011        0.047446
# Infant mortality (per 1000 births)   -0.051547    0.022997       -0.007160
# GDP ($ per capita)                   -0.052887   -0.039324        0.072185
# Literacy (%)                          0.037566   -0.043381        0.035787
# Phones (per 1000)                    -0.051663   -0.030807        0.053364
# Arable (%)                            0.005567    0.187546       -0.080772
# ...

# %% [markdown]
# # Correlation heatmap

# %% [markdown]
# Visualizing variables using scatter plots

# %%
fig, ax = plt.subplots(figsize=(14,14)) 
sns.heatmap(df.corr(), annot=True, ax=ax).set(
    title = 'Correlation', xlabel = 'Columns', ylabel = 'Columns')
plt.show()

# %% [markdown]
# # Linear relationship between an individual variable and GDP ($ per capita) using\
# "regplot", which plots the scatterplot plus the fitted regression line for the data.

# %% [markdown]
# # Positive and Negative linear relationships

# %% [markdown]
# Phones (per 1000) as potential explanatory variable of GDP ($ per capita)

# %%
sns.regplot(x="Phones (per 1000)", y="GDP ($ per capita)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 57842.349390839176)

# %% [markdown]
# This depicts a positive direct correlation between the two variables. As the number of phones (per 1000) goes up, the GDP per capita goes up
# therefore, phones per 1000 could potentially be a good predictor of GDP per capita.

# %% [markdown]
# Appreciating the correlation between Phones and GDP ($ per capita)

# %%
df[["Phones (per 1000)", "GDP ($ per capita)"]].corr()
# Out:
#                     Phones (per 1000)  GDP ($ per capita)
# Phones (per 1000)            1.000000            0.830549
# GDP ($ per capita)           0.830549            1.000000

# %%
# Net Migration as the potential predictor of GDP($ per capita)
sns.regplot(x="Net migration", y="GDP ($ per capita)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 58623.95931531104)

# %% [markdown]
# This depicts a positive direct correlation between the two variables. As the Net migration goes up, the GDP per capita goes up.
# therefore, Net Migration seems to be a weak predictor of GDP per capita
# In countries where they are experiencing high net migrations, their GDP per capita is also high

# %%
df[["Net migration", "GDP ($ per capita)"]].corr()
# Out:
#                     Net migration  GDP ($ per capita)
# Net migration            1.000000            0.381969
# GDP ($ per capita)       0.381969            1.000000

# %%
# Infant mortality (per 1000 births) as a potential predictor of GDP ($ per capita)
sns.regplot(x="Infant mortality (per 1000 births)", y="GDP ($ per capita)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 58983.23835102097)

# %% [markdown]
# This is a negative relationship existing between Infant mortality per 1000 births and GDP per capita.
# In countires where there is high infant mortality rate, GDP per capita is low, a moderate predictor of GDP ($ per capita)

# %%
df[["Infant mortality (per 1000 births)", "GDP ($ per capita)"]].corr()
# Out:
#                                     Infant mortality (per 1000 births)  \
# Infant mortality (per 1000 births)                            1.000000
# GDP ($ per capita)                                           -0.600002
#
#                                     GDP ($ per capita)
# Infant mortality (per 1000 births)           -0.600002
# GDP ($ per capita)                            1.000000

# %%
# Birthrate as a potential predictor of GDP ($ per capita)
sns.regplot(x="Birthrate", y="GDP ($ per capita)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 58312.53623481932)

# %% [markdown]
# There is a negative relationship (moderate) between birthrate and GDP per capita. In a country where there is high birthrate, the GDP per capita is low
# The birthrate seems to be a good variable to explain GDP per capita

# %%
df[["Birthrate", "GDP ($ per capita)"]].corr()
# Out:
#                     Birthrate  GDP ($ per capita)
# Birthrate            1.000000           -0.648808
# GDP ($ per capita)  -0.648808            1.000000

# %%
# Service as a potential predictor of GDP ($ per capita)
sns.regplot(x="Service", y="GDP ($ per capita)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 58388.74708282926)

# %% [markdown]
# There is a positive relationship between countires whose economy is service oriented and the GDP per capita and the relationship is moderately strong
# Service is potentially a good predictor of GDP per capita

# %%
df[["Service", "GDP ($ per capita)"]].corr()
# Out:
#                      Service  GDP ($ per capita)
# Service             1.000000            0.531357
# GDP ($ per capita)  0.531357            1.000000

# %%
# Agriculture as a potential predictor of GDP ($ per capita)
sns.regplot(x="Agriculture", y="GDP ($ per capita)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 58881.211292569365)

# %%
df[["Agriculture", "GDP ($ per capita)"]].corr()
# Out:
#                     Agriculture  GDP ($ per capita)
# Agriculture            1.000000           -0.570735
# GDP ($ per capita)    -0.570735            1.000000

# %% [markdown]
# There is a negative relationship between Agriculture and GDP per capita. Thus in countries whose economy is predominantly agriculture, the GDP per capita
# is generally low

# %%
# Literacy as a potential predictor of GDP ($ per capita)
sns.regplot(x="Literacy (%)", y="GDP ($ per capita)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 58366.650515724206)

# %% [markdown]
# In countries with high literacy levels, the GDP per capita is also high thus there is a positive relationship between literacy levels and GDP per capita
# As literacy levels increase, GDP per capita also increases
# Literacy levels seems to be a potential predictor of GDP per capita

# %%
df[["Literacy (%)", "GDP ($ per capita)"]].corr()
# Out:
#                     Literacy (%)  GDP ($ per capita)
# Literacy (%)            1.000000            0.497963
# GDP ($ per capita)      0.497963            1.000000

# %%
# Population as a potential predictor of GDP ($ per capita)
sns.regplot(x="Population", y="GDP ($ per capita)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 58637.349118486556)

# %% [markdown]
# A negative relationship between population and GDP per capita. Countires with high population low high GDP per capita

# %%
df[["Population", "GDP ($ per capita)"]].corr()
# Out:
#                     Population  GDP ($ per capita)
# Population            1.000000           -0.039324
# GDP ($ per capita)   -0.039324            1.000000

# %% [markdown]
# # Categorical Variables

# %%
#Relationship between Region and GDP per capita using boxplot

# %%
sns.boxplot(x="Region", y="GDP ($ per capita)", data=df, width=0.7,palette="Set3",fliersize=5)
plt.xticks(rotation=90)
plt.title("Regional Average GDP per Capita")
# Out:
# Text(0.5, 1.0, 'Regional Average GDP per Capita')

# %% [markdown]
# Developed regions have high GDP per capita than developing regions.

# %% [markdown]
# # Descriptive Statistical Analysis

# %% [markdown]
# # Getting basic statistics for all continuous variables
# Count of that variable\
# Mean\
# Standard Deviation\
# Minimum Value\
# The Interquartile range (25%, 50%, 75%)

# %%
df.describe()
# Out:
#        Unnamed: 0    Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  226.000000  2.260000e+02    2.260000e+02                  226.000000
# mean   112.513274  2.886625e+07    5.996970e+05                  380.719912
# std     65.407592  1.181377e+08    1.794119e+06                 1663.679301
# min      0.000000  7.026000e+03    2.000000e+00                    0.000000
# 25%     56.250000  4.425318e+05    4.407250e+03                   29.725000
# 50%    112.500000  4.914957e+06    8.523500e+04                   79.150000
# 75%    168.750000  1.757631e+07    4.441805e+05                  190.975000
# max    226.000000  1.313974e+09    1.707520e+07                16271.500000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                    226.000000     226.000000
# mean                      21.257124       0.038125
# std                       72.434062       4.867491
# min                        0.000000     -20.990000
# ...

# %%
df.describe(include=['object'])
# Out:
#                 Country                               Region  \
# count               226                                  226
# unique              226                                   11
# top     Czech Republic   SUB-SAHARAN AFRICA
# freq                  1                                   51
#
#        Literacy (%) -binned
# count                   226
# unique                    3
# top                     Low
# freq                    173

# %% [markdown]
# # Value Counts

# %%
df['Region'].value_counts()
# Out:
# SUB-SAHARAN AFRICA                     51
# LATIN AMER. & CARIB                    45
# ASIA (EX. NEAR EAST)                   28
# WESTERN EUROPE                         28
# OCEANIA                                21
# NEAR EAST                              16
# C.W. OF IND. STATES                    12
# EASTERN EUROPE                         12
# NORTHERN AMERICA                        5
# NORTHERN AFRICA                         5
# BALTICS                                 3
# Name: Region, dtype: int64

# %% [markdown]
# # Group Analysis

# %%
df_group_one = df[['Region','GDP ($ per capita)']]

# %%
df_group_one = df_group_one.groupby(['Region'],as_index=False).mean()
df_group_one
# Out:
#                                  Region  GDP ($ per capita)
# 0         ASIA (EX. NEAR EAST)                  8053.571429
# 1   BALTICS                                    11300.000000
# 2                  C.W. OF IND. STATES          4000.000000
# 3   EASTERN EUROPE                              9808.333333
# 4               LATIN AMER. & CARIB             8682.222222
# 5   NEAR EAST                                  10456.250000
# 6   NORTHERN AFRICA                             5460.000000
# 7   NORTHERN AMERICA                           26100.000000
# 8   OCEANIA                                     8247.619048
# 9   SUB-SAHARAN AFRICA                          2323.529412
# 10  WESTERN EUROPE                             27046.428571

# %% [markdown]
# # A quick overview of GDP ($ per capita) per region using a barchart and other visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
fig = plt.figure(figsize=(10, 4))
df.groupby('Region')['GDP ($ per capita)'].mean().sort_values().plot(kind='bar')
plt.title('Regional Average GDP per Capita')
plt.xlabel("Region")
plt.ylabel('Average GDP per Capita')
plt.show()

# %% [markdown]
# From the analysis, on average, Western Europe has the highest GDP per capita.

# %%
fig = plt.figure(figsize=(10, 6))
plt.title('Regional Analysis')
ax1 = fig.add_subplot
sns.countplot(data= df, y= 'Region')
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
plt.title('Regional Analysis')
ax1 = fig.add_subplot
sns.barplot(data= df, y= 'Region', x= 'Population', ci= None)
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
plt.title('Regional Analysis')
ax1 = fig.add_subplot
sns.barplot(data= df, y= 'Region', x= 'Service', ci= None)
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
plt.title('Regional Analysis')
ax1 = fig.add_subplot
sns.barplot(data= df, y= 'Region', x= 'Net migration', ci= None)
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
plt.title('Regional Analysis')
ax1 = fig.add_subplot
sns.barplot(data= df, y= 'Region', x= 'Infant mortality (per 1000 births)', ci= None)
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
plt.title('Regional Analysis')
ax1 = fig.add_subplot
sns.barplot(data= df, y= 'Region', x= 'Phones (per 1000)', ci= None)
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
plt.title('Regional Analysis')
ax1 = fig.add_subplot
sns.barplot(data= df, y= 'Region', x= 'Literacy (%)', ci= None)
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
plt.title('Regional Analysis')
ax1 = fig.add_subplot
sns.barplot(data= df, y= 'Region', x= 'Birthrate', ci= None)
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
plt.title('Regional Analysis')
ax1 = fig.add_subplot
sns.barplot(data= df, y= 'Region', x= 'GDP ($ per capita)', ci= None)
plt.show()

# %% [markdown]
# ## Distribution Analysis of Variables using Histogram

# %%
fig = plt.figure(constrained_layout=True, figsize=(16,6))
grid = gridspec.GridSpec(ncols=3, nrows=1, figure=fig)
ax1 = fig.add_subplot(grid[0, :2])
ax1.set_title('Histogram')
sns.distplot(df.loc[:,'GDP ($ per capita)'], norm_hist=True, ax = ax1)
plt.show()
# Out:
# C:\Users\kmalangwasila\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig = plt.figure(figsize=(16,30))
features= ["Population","Area (sq. mi.)","Net migration","Infant mortality (per 1000 births)", "Literacy (%)", "Phones (per 1000)","Other (%)","Climate","Birthrate","Deathrate","Agriculture","Industry","Service"]

for i in range(len(features)):
    fig.add_subplot(9, 5, i+1)
    sns.distplot(df[features[i]])
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kmalangwasila\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kmalangwasila\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Most of the variables not normally distributed

# %% [markdown]
# # Correlation and Casuation

# %%
df.corr()
# Out:
#                                     Unnamed: 0  Population  Area (sq. mi.)  \
# Unnamed: 0                            1.000000   -0.041546       -0.044319
# Population                           -0.041546    1.000000        0.469883
# Area (sq. mi.)                       -0.044319    0.469883        1.000000
# Pop. Density (per sq. mi.)            0.018191   -0.028442       -0.067118
# Coastline (coast/area ratio)          0.037794   -0.068528       -0.095889
# Net migration                        -0.017198    0.000011        0.047446
# Infant mortality (per 1000 births)   -0.051547    0.022997       -0.007160
# GDP ($ per capita)                   -0.052887   -0.039324        0.072185
# Literacy (%)                          0.037566   -0.043381        0.035787
# Phones (per 1000)                    -0.051663   -0.030807        0.053364
# Arable (%)                            0.005567    0.187546       -0.080772
# ...

# %% [markdown]
# # Determining the significance of correlation using P values
# The P-value is the probability value that the correlation between these two variables is statistically significant

# %% [markdown]
# Using the significance level of 0.05, implies that we are confident that the correlation between the two variables is significant

# %% [markdown]
# P values and interpretations

# %% [markdown]
# P-value <0.001: implies strong evidence that the correlation is significant\
# P-value <0.05: implies moderate evidence that the correlation is significant\
# P_value <0.1: there is weak evidence that the correlation is significant\
# P_value > 0.1: there is no evidence that the correlation is significant

# %% [markdown]
# Importing "stats" module in the scipy Library to obtain the P-values

# %%
from scipy import stats

# %% [markdown]
# # Phones (per 1000) vs GDP ($ per capita)

# %%
pearson_coef, p_value = stats.pearsonr(df["Phones (per 1000)"], df['GDP ($ per capita)'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8305487843788759  with a P-value of P = 7.382745002779456e-59

# %% [markdown]
# Conclusion:
#
# From the output, P-value is <0.001, the correlation between Phones (per 1000)
# and GDP per capita is statisitcally significant and the linear relationship is very strong
# (0.8305)

# %% [markdown]
# # Literacy (%) vs GDP ($ per capita)

# %%
pearson_coef, p_value = stats.pearsonr(df["Literacy (%)"], df['GDP ($ per capita)'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.49796278849287223  with a P-value of P = 1.4521951839259384e-15

# %% [markdown]
# Conclusion:
# P-value is <0.001, indicating correlation between Literacy and GDP per capita
# is statistically significant though the linear relationship is moderate (~0.5

# %% [markdown]
# # Net Migration vs GDP ($ per capita)

# %%
pearson_coef, p_value = stats.pearsonr(df["Net migration"], df['GDP ($ per capita)'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.3819693733063831  with a P-value of P = 2.901615093719576e-09

# %% [markdown]
# Concluson:
# P-value is < 0.001 indicating correlation between Net migrations
# and GDP per capita is statisitcally significant, however the linear relationship is not very strong

# %% [markdown]
# # Service vs GDP ($ per capita)

# %%
pearson_coef, p_value = stats.pearsonr(df["Service"], df['GDP ($ per capita)'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5313568802742648  with a P-value of P = 7.229019849099483e-18

# %% [markdown]
# Conclusion:
# From the output,
# Since the P-value is <0.001, the correlation between
# service dominant economies and GDP per capita is statistically significant
# and the linear relationship between the two variables is moderate (~0.5)

# %% [markdown]
# # Infant mortality (per 1000 births vs GDP ($ per capita)

# %%
pearson_coef, p_value = stats.pearsonr(df["Infant mortality (per 1000 births)"], df['GDP ($ per capita)'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.6000016483489914  with a P-value of P = 1.725176305849577e-23

# %% [markdown]
# Conclusion:
# From the output,
# Since the P-value is <0.001, the correlation between Infant mortality
# and GDP $ per capita is statistically significant, and the linear relationship is negative and moderately strong

# %% [markdown]
# # Birthrate Vs GDP ($ per capita)

# %%
pearson_coef, p_value = stats.pearsonr(df["Birthrate"], df['GDP ($ per capita)'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.6488082145251746  with a P-value of P = 2.16587487729975e-28

# %% [markdown]
# Conclusion: P-value is <0.001, the correlation between Birthrate and GDP ($ per capita) is statistically significant, and the relationship is negative and moderately strong

# %% [markdown]
# # Agriculture Vs GDP ($ per capita)

# %%
pearson_coef, p_value = stats.pearsonr(df["Agriculture"], df['GDP ($ per capita)'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.5707350118232838  with a P-value of P = 6.234266949144558e-21

# %% [markdown]
# P-value <0.001: The correlation between Agriculture and GDP ($ per capita) is statistically strong and the linear relationship is moderately strong and it is negative

# %% [markdown]
# # Population Vs GDP ($ per capita)

# %%
pearson_coef, p_value = stats.pearsonr(df["Population"], df['GDP ($ per capita)'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.03932445852671178  with a P-value of P = 0.5564479500026606

# %% [markdown]
# Conclusion: P-value >0.1 means that there is no evidence that the correlation is siginificant

# %% [markdown]
# # Important Variables to consider for model development in predicting GDP ($ per capita)

# %% [markdown]
# Variables that significantly affect our Target Variable (GDP ($per capita)
#
# Service\
# Phones (per 1000)\
# Literacy\
# Net Migration\
# Infant Mortality (per 1000 births)\
# Birthrate\
# Agriculture

# %% [markdown]
# ## 3. Model Development

# %% [markdown]
# Prediction Models

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#    Unnamed: 0          Country                               Region  \
# 0           0     Afghanistan         ASIA (EX. NEAR EAST)
# 1           1         Albania   EASTERN EUROPE
# 2           2         Algeria   NORTHERN AFRICA
# 3           3  American Samoa   OCEANIA
# 4           4         Andorra   WESTERN EUROPE
#
#    Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0    31056997          647500                        48.0
# 1     3581655           28748                       124.6
# 2    32930091         2381740                        13.8
# 3       57794             199                       290.4
# 4       71201             468                       152.1
#
#    Coastline (coast/area ratio)  Net migration  \
# 0                          0.00          23.06
# 1                          1.26          -4.93
# 2                          0.04          -0.39
# 3                         58.29         -20.71
# 4                          0.00           6.60
#
# ...

# %% [markdown]
# # Linear Regression and Multiple Linear Regression

# %% [markdown]
# # Simple Linear Regression
# Predicting GDP($ per capita) using one explanatory variable

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Creating linear regression object

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %% [markdown]
# # Predicting GDP($ per capita) using Phones (per 1000) as an explanatory variable

# %%
X = df[['Phones (per 1000)']]
Y = df['GDP ($ per capita)']

# %% [markdown]
# Fitting the regression with Literacy (%)

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# Giving a prediction

# %%
Yhat=lm.predict(X)
Yhat[0:7]
# Out:
# array([ 1107.85208638,  3613.95200277,  3868.24743546, 10553.63750654,
#        19313.93089075,  1277.38237484, 17942.94681884])

# %% [markdown]
# Value of the intercept a

# %%
lm.intercept_
# Out:
# 989.9179726686216

# %% [markdown]
# Value of the coefficient b

# %%
lm.coef_
# Out:
# array([36.85441054])

# %% [markdown]
# # Estimated Simple Linear Model will be
# Yhat = a + bX
#
# Where;\
# a = intercept, value of Yhat when X is zero
# b = cofficient of X thus, value of GDP per capita when phones change by one unit

# %% [markdown]
# GDP ($ per capita) = 989.92 + 36.85Phones

# %% [markdown]
# # Predicting GDP($ per capita) using Literacy (%) as an explanatory variable

# %%
X = df[['Literacy (%)']]
Y = df['GDP ($ per capita)']

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# Giving a prediction

# %%
Yhat=lm.predict(X)
Yhat[0:10]
# Out:
# array([-2670.5468787 , 10656.13190794,  6301.8705222 , 13427.02551704,
#        14218.70940535, -1087.17910207, 12899.23625816, 11315.86848153,
#        13453.41497998, 13849.25692414])

# %% [markdown]
# Getting the value of the intercept

# %%
lm.intercept_
# Out:
# -12170.753538472767

# %% [markdown]
# Getting the coefficient

# %%
lm.coef_
# Out:
# array([263.89462944])

# %% [markdown]
# # Estimated Simple Linear Model will be
# GDP (% per capita) = a + bLiteracy(%)
#
# Where;\
# a = intercept, value of GDP (% per capita) when Literacy is zero
# b = cofficient of X thus, value of GDP per capita when Literacy (%) changes by 1%

# %% [markdown]
# GDP ($ per capita) = -12170.75 + 263.89Literacy (%)

# %% [markdown]
# # Predicting GDP($ per capita) using Service as an explanatory variable

# %%
X = df[['Service']]
Y = df['GDP ($ per capita)']

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# Getting an output as a prediction

# %%
Yhat=lm.predict(X)
Yhat[0:5]
# Out:
# array([ 3488.69626776, 10120.86923596,   755.84107484,  9689.82300885,
#         9689.82300885])

# %% [markdown]
# Getting the value of the intercept

# %%
lm.intercept_
# Out:
# -9175.754626280766

# %%
lm.coef_
# Out:
# array([33327.50235275])

# %% [markdown]
# # Estimated Simple Linear Model will be
# GDP (% per capita) = a + b x Service
#
# Where;\
# a = intercept, value of GDP (% per capita) when Service is zero
# b = cofficient of X thus, value of GDP per capita when service changes by one unit

# %% [markdown]
# GDP ($ per capita) = -9175 + 33327 x Service

# %% [markdown]
# # Multiple Linear Regression
# Prediciting the GDP ($ per capita ) using more than one predictors

# %% [markdown]
# Yhat = a + b1X1 + b2X2 + b3X3 + b4X4

# %% [markdown]
# Phones (per 1000)\
# Literacy (%)\
# Service\
# Birthrate

# %% [markdown]
# Developing the model using these variables as predictors of GDP (% per capita)

# %%
Z = df[['Phones (per 1000)', 'Literacy (%)', 'Service', 'Birthrate']]

# %%
lm.fit(Z, df['GDP ($ per capita)'])
# Out:
# LinearRegression()

# %% [markdown]
# Getting the intercept (a)

# %%
lm.intercept_
# Out:
# 3159.190789278573

# %% [markdown]
# Getting the coefficients, b1, b2, b3, b4

# %%
lm.coef_
# Out:
# array([ 33.56602032,   5.70621274,  23.32318547, -84.96173486])

# %% [markdown]
# # Estimated multiple linear regression will be

# %% [markdown]
# GDP ($ per capita) = 3159.19 + 33.56602032 x Phones (per 1000) + 5.70621274 x Literacy (%) + 23.32318547 x Service -84.96173486 x Birthrate

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# # Using R squared to measure accuaracy of the model
# R squared or coefficient of determination, is a measure to indicate how close the data is to the fitted regression line.</p>
#
# <p>The value of the R-squared is the percentage of variation of the response variable (y) that is explained by a linear model

# %% [markdown]
# Calculating the R^2

# %%
lm.fit(X, Y)
# Find the R^2
print('The R-square is: ', lm.score(X, Y))
# Out:
# The R-square is:  0.2823401342147993

# %% [markdown]
# Using the simple linear regression, 28% of the variations of the GDP ($ per capita) are being explained by the linear model

# %% [markdown]
# Under Multiple Linear Regression Model

# %%
# fit the model 
lm.fit(Z, df['GDP ($ per capita)'])
# Find the R^2
print('The R-square is: ', lm.score(Z, df['GDP ($ per capita)']))
# Out:
# The R-square is:  0.6948572546910541

# %% [markdown]
# About 70% of the variations in GDP($ per capita) are being explained by multiple linear regression

# %% [markdown]
# # Mean Square Error
# The MSE measures the average of the squares of errors, that is, the difference between the actual values of GDP per
# capita and the estimated value of GDP per capita

# %% [markdown]
# MSE under Simple Linear Regression

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(df['GDP ($ per capita)'], Yhat)
print('The mean square error of GDP per capita and predicted value is: ', mse)
# Out:
# The mean square error of GDP per capita and predicted value is:  72152337.15704115

# %% [markdown]
# MSE under Multiple Linear Regression

# %%
Y_predict_multifit = lm.predict(Z)

# %%
print('The mean square error of GDP ($ per capita) and predicted value using multifit is: ', \
      mean_squared_error(df['GDP ($ per capita)'], Y_predict_multifit))
# Out:
# The mean square error of GDP ($ per capita) and predicted value using multifit is:  30678547.443178236

# %% [markdown]
# Conclusion: The MSE of MLR is lower than MSE of SLR. Together with R-squared and MSE, the MLR is proving
#     to be a better model fit than SLR

# %%
Y_hat = lm.predict(Z)

# %%
width = 12
height = 10

# %%
plt.figure(figsize= (width, height))


ax1 = sns.distplot(df['GDP ($ per capita)'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for GDP ($ per capita)')
plt.xlabel('GDP ($ per capita)')
plt.ylabel('Distribution')

plt.show()
plt.close()
# Out:
# C:\Users\kmalangwasila\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kmalangwasila\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
